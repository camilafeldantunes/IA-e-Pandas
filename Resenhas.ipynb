# %% [markdown]
# <a href="https://colab.research.google.com/github/camilafeldantunes/IA-e-Pandas/blob/main/Resenhas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df_reviews = pd.read_csv("/content/reviews.csv")

# %%
coluna_reviews = df_reviews["reviewText"]
coluna_reviews
# Out:
# 0     it works as expected. I should have sprung for...
# 1     This think has worked out great.Had a diff. br...
# 2     Bought it with Retail Packaging, arrived legit...
# 3     It's mini storage.  It doesn't do anything els...
# 4     I have it in my phone and it never skips a bea...
# 5     It works, but file writes are a bit slower tha...
# 6     I bought 2 of those SanDisk 32 GB microSD , us...
# 7     The memory card is an excellent condition and ...
# 8     I bougth this micro SD card after some trubles...
# 9     Ordered this for a Galaxy S3.  Lasted a few mo...
# 10    more like 8mb/s in my Note 10.1 and that's usi...
# 11    I used this for a few months in my phone, then...
# 12    everything about it was great, except for the ...
# 13    Used in my phone it's plenty fast and works ju...
# 14    This card advertises itself as UHS1 but it's a...
# 15    I bought this SD card for my android phone thi...
# 16    good card. work as describes. haven't had any ...
# ...

# %%
# !pip install -q groq
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.3/138.3 kB 3.3 MB/s eta 0:00:00

# %%
import os
from google.colab import userdata
os.environ["GROQ_API_KEY"] = userdata.get('GROQ_API_KEY')

# %%
from groq import Groq

client = Groq()

def resposta_perguntas(coluna_reviews):
    lista_respostas = []
    lista_sentimentos = []

    for i, resenha in enumerate(coluna_reviews):

        completion = client.chat.completions.create(
            model="openai/gpt-oss-20b",
            messages=[
                {
                    "role": "user",
                    "content": resenha + ". Responda essa resenha com: Neutro, Positivo ou Negativo"
                },
            ],
            temperature=1,
            max_completion_tokens=8192,
            top_p=1,
            reasoning_effort="medium",
            stream=True
        )


        resposta_texto = ""

        for chunk in completion:
            conteudo = chunk.choices[0].delta.content or ""

            resposta_texto += conteudo



        lista_respostas.append({
            "Resenha": resenha,
            "Resposta": resposta_texto
        })
        lista_sentimentos.append(resposta_texto)


    return lista_sentimentos

# %%
resposta_perguntas(coluna_reviews)
# Out:
# ['Negativo',
#  'Positivo',
#  'Positivo',
#  'Positivo',
#  'Positivo',
#  'Negativo',
#  'Negativo',
#  'Positivo',
#  'Negativo',
#  'Negativo',
#  'Neutro',
#  'Negativo',
#  'Neutro',
#  'Positivo',
#  'Negativo',
#  'Negativo',
#  'Positivo',
#  'Positivo',
#  'Negativo',
#  'Positivo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Neutro',
#  'Positivo',
#  'Negativo',
#  'Negativo',
#  'Positivo',
#  'Neutro',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Neutro',
#  'Negativo',
#  'Negativo']

# %%
df_reviews["sentimentos"] = resposta_perguntas(coluna_reviews)

# %%
df_reviews
# Out:
#         reviewerID        asin                       reviewerName  \
# 0   A2FII3I2MBMUIA  B007WTAJTO                                1K3
# 1    A3H99DFEG68SR  B007WTAJTO                                1m2
# 2   A375ZM4U047O79  B007WTAJTO                       2&amp;1/2Men
# 3   A2IDCSC6NVONIZ  B007WTAJTO                            2Cents!
# 4   A26YHXZD5UFPVQ  B007WTAJTO                         2K1Toaster
# 5   A2Q3ICGWZLY3JJ  B007WTAJTO                              98020
# 6    AF24M1HKIZ7QC  B007WTAJTO  Abdulrahman J. Alrashed "dr34m3r"
# 7   A1KIF9Z5VFPH7H  B007WTAJTO        Abel Feliciano "Ace Master"
# 8   A1FKE13D77L3Y3  B007WTAJTO          Abraham Arturo Meza Marin
# 9   A1X1FX3NSOFCT3  B007WTAJTO  Abused Commuter "abused_commuter"
# 10  A3RV1L35IPTV61  B007WTAJTO                         abushaheed
# 11  A2RJ7DAL63MN1F  B007WTAJTO                      Ace of Sevens
# 12  A3IJIFZ5HH819V  B007WTAJTO                             A. Cho
# ...

# %%
df_reviews_negativo = df_reviews[df_reviews["sentimentos"] == "Negativo"] ##pegando somente as reviews negativas

# %%
resenhas_negativas = df_reviews_negativo["reviewText"] ## passando essas reviews para uma variavel

# %%
df_reviews_negativo.shape
# Out:
# (24, 10)

# %%
resenhas_unidas = "#####".join(resenhas_negativas) ##juntando essas reviews com o .join()

# %%
## pedindo para LLM alocar essas reviews em 5 categorias
completion = client.chat.completions.create(
            model="openai/gpt-oss-20b",
            messages=[
                {
                    "role": "user",
                    "content": f"""Você é um analista de dados. vou te passar varias resenhas e preciso
                    que voce agrupe elas em 5 categorias diferentes para os tipos de reclamacoes. quero que voce
                    me retorne as 5 categorias. aqui estao as resenhas {resenhas_unidas}  as resenhas estao separadas
                    por '#####'. quero que voce me retorne tambem para que cada categoria seja definida em UMA PALAVRA, alem disso
                    nao escreva mais nada alem das 5 categorias e em portugues por favor"""
                },
            ],
            temperature=1,
            max_completion_tokens=8192,
            top_p=1,
            reasoning_effort="medium",
            stream=True
        )
resposta_texto = ""

for chunk in completion:
    conteudo = chunk.choices[0].delta.content or ""

    resposta_texto += conteudo

print(resposta_texto)
categorias_negativas = resposta_texto ## salvando essas reviews em uma variavel
# Out:
# Velocidade
# Durabilidade
# Compatibilidade
# Capacidade
# Suporte

# %%
lista_negativas = categorias_negativas.split('\n') ##passando as 5 categorias para uma lista

# %%
lista_negativas
# Out:
# ['Velocidade', 'Durabilidade', 'Compatibilidade', 'Capacidade', 'Suporte']

# %%
completion = client.chat.completions.create(
            model="openai/gpt-oss-20b",
            messages=[
                {
                    "role": "user",
                    "content": f"""Você é um analista de dados. vou te passar varias resenhas e preciso
                    que voce agrupe elas em 5 categorias diferentes para os tipos de reclamacoes. E que cada
                    categoria seja feita somente por uma palavra.

                    Depois me retorne apenas um texto no formato json contento 3 chaves
                    - resenha original = ira conter a resenha original em ingles
                    - categoria = ira conter a cartegoria que voce classificou a resenha em portugues tambem.


                    aqui estao as resenhas {resenhas_unidas}  as resenhas estao separadas
                    por '#####'.

                    alem disso nao retorne mais nada alem do texto json """

                },
            ],
            temperature=1,
            max_completion_tokens=8096,
            top_p=1,
            reasoning_effort="medium",
            stream=True
        )
resposta_texto = ""

for chunk in completion:
    conteudo = chunk.choices[0].delta.content or ""

    resposta_texto += conteudo

print(resposta_texto)
texto_json = resposta_texto ## salvando essas reviews em uma variavel
# Out:
# ```json
# [
#   {
#     "resenha original": "It works, but file writes are a bit slower than expected on a USB3 reader.Also, both reads and writes are FASTER with the card inside the standard-size SD adapter (15 MB/s vs 10 write; 45 MB/s vs 22 MB/s read) on the same card reader.  Can't figure why...",
#     "categoria": "Desempenho"
#   },
#   {
#     "resenha original": "I bought 2 of those SanDisk 32 GB microSD , used them on my Galaxy Note and Galaxy S4First one , my phone started saying it was removed , then recognize it again :) then diedI thought it's just a luck , plugged in the 2nd one :) stayed for about 2 months and died suddenly ! and lost everythingnever buying from SanDisk again .. ever",
#     "categoria": "Durabilidade"
#   },
#   {
# ...

# %%
import json

texto_json_limpo = texto_json.replace('```json','').replace("```","").strip() ##removendo o texto que nao queremos



dicionario_resenhas_negativas = json.loads(texto_json_limpo) ##transformando o texto em um dicionario

# %%
len(dicionario_resenhas_negativas)
# Out:
# 25
